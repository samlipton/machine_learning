# %% [markdown]
# # Neural Networks
#
# To classify data based on **Neural Networks** (NN) using modular architecture, the `classifier` package is imported.

# %%
# %%capture
import sys
sys.path.append("../projects/")

import classifier as clf
